# %% [markdown]
# # Download data from TCIA
#
# This example Jupyter notebook demonstrates how to download data from The Cancer Imaging Archive (TCIA). Finally the data is visualised using the ImageVisualiser class within PlatiPy

# %%
# Is platipy alread installed in your environment? If not run this cell to install it.
# !pip install git+https://github.com/pyplati/platipy.git

# %% [markdown]
# ### Import some functions to be able to download and visualise data

# %%
import SimpleITK as sitk

from platipy.dicom.download.tcia import (
    get_collections,
    get_modalities_in_collection,
    get_patients_in_collection,
    fetch_data
)
from platipy.imaging.visualisation.tools import ImageVisualiser
from platipy.imaging.utils.tools import get_com

# %% [markdown]
# ## Let's get a list of all collections available in TCIA
#
# You can also browse the list of collections available here: https://www.cancerimagingarchive.net/collections/

# %%
collections = get_collections()

# %% [markdown]
# ## We'll use the 'Head-Neck Cetuximab' collection
#
# In this cell we check what modalities are available with the collection

# %%
collection = 'Head-Neck Cetuximab'
modalities = get_modalities_in_collection(collection)
print(f"Modalities available: {modalities}")
# Out:
# Modalities available: ['PT', 'CT', 'RTDOSE', 'RTPLAN', 'RTSTRUCT']

# %% [markdown]
# ## Next let's see find the patients available in the collection

# %%
patients = get_patients_in_collection(collection)

# %% [markdown]
# ## Download the CT, RTSTRUCT and RTDOSE for the first patient
#
# The fetch_data function will download the DICOM data from TCIA and will then convert it to NIFTI format for use within platipy.

# %%
patient_id = patients[0]
data = fetch_data(
    collection,
    patient_ids=[patient_id],
    modalities=["CT", "RTSTRUCT", "RTDOSE"],
    nifti=True
)
# Out:
# :12.837 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 688
# 2021-02-19 05:34:12.876 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 689
# 2021-02-19 05:34:12.907 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 690
# 2021-02-19 05:34:12.925 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 691
# 2021-02-19 05:34:12.937 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 692
# 2021-02-19 05:34:12.972 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 693
# 2021-02-19 05:34:13.007 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 694
# 2021-02-19 05:34:13.030 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 695
# 2021-02-19 05:34:13.050 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 696
# 2021-02-19 05:34:13.062 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 697
# 2021-02-19 05:34:13.089 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 698
# 2021-02-19 05:34:13.110 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 699
# 2021-02-19 05:34:13.135 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 700
# 2021-02-19 05:34:13.153 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 701
# 2021-02-19 05:34:13.165 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 702
# 2021-02-19 05:34:13.172 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 703
# 2021-02-19 05:34:13.178 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 704
# 2021-02-19 05:34:13.194 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 705
# 2021-02-19 05:34:13.206 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 706
# 2021-02-19 05:34:13.231 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 707
# 2021-02-19 05:34:13.246 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 708
# 2021-02-19 05:34:13.259 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 709
# 2021-02-19 05:34:13.279 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 710
# 2021-02-19 05:34:13.312 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 711
# 2021-02-19 05:34:13.326 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 712
# 2021-02-19 05:34:13.334 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 713
# 2021-02-19 05:34:13.351 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 714
# 2021-02-19 05:34:13.376 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 715
# 2021-02-19 05:34:13.416 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 716
# 2021-02-19 05:34:13.434 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 717
# 2021-02-19 05:34:13.446 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 718
# 2021-02-19 05:34:13.452 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 719
# 2021-02-19 05:34:13.459 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 720
# 2021-02-19 05:34:13.467 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 721
# 2021-02-19 05:34:13.489 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 722
# 2021-02-19 05:34:13.513 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 723
# 2021-02-19 05:34:13.528 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 724
# 2021-02-19 05:34:13.544 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 725
# 2021-02-19 05:34:13.573 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 726
# 2021-02-19 05:34:13.584 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 727
# 2021-02-19 05:34:13.606 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 728
# 2021-02-19 05:34:13.647 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 729
# 2021-02-19 05:34:13.658 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 730
# 2021-02-19 05:34:13.665 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 731
# 2021-02-19 05:34:13.671 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 732
# 2021-02-19 05:34:13.675 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 733
# 2021-02-19 05:34:13.728 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 734
# 2021-02-19 05:34:13.738 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 735
# 2021-02-19 05:34:13.744 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 736
# 2021-02-19 05:34:13.763 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 737
# 2021-02-19 05:34:13.941 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_file_list:276 -   Sorting file 738
# 2021-02-19 05:34:13.950 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:752 - Processing data for PatientName = 0522c0001.
# 2021-02-19 05:34:13.954 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:753 -   Number of DICOM series = 6
# 2021-02-19 05:34:13.958 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:765 -   Output image name format: {parent_sorting_data}_{study_uid_index}_{Modality}_{image_desc}_{SeriesNumber}
# 2021-02-19 05:34:13.959 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:766 -   Output structure name format: {parent_sorting_data}_{study_uid_index}_{Modality}_{structure_name}
# 2021-02-19 05:34:13.961 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:767 -   Output dose name format: {parent_sorting_data}_{study_uid_index}_{DoseSummationType}
# 2021-02-19 05:34:13.963 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:312 -   Processing series UID: 1.3.6.1.4.1.14519.5.2.1.5099.8010.279840345131785576013456733353
# 2021-02-19 05:34:13.966 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:318 -   Number of DICOM files: 404
# 2021-02-19 05:34:13.977 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:340 -   SOP Class name: CT Image Storage
# 2021-02-19 05:34:18.399 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:828 -   Setting study instance UID index: 0
# 2021-02-19 05:34:18.403 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:get_dicom_info_from_description:31 -     Image modality: CT
# 2021-02-19 05:34:18.405 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:312 -   Processing series UID: 1.3.6.1.4.1.14519.5.2.1.5099.8010.293653169363509354643731389289
# 2021-02-19 05:34:18.406 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:318 -   Number of DICOM files: 113
# 2021-02-19 05:34:18.421 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:340 -   SOP Class name: CT Image Storage
# 2021-02-19 05:34:19.715 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:812 -   Parent sorting field (PatientName) match found: 0522C0001
# 2021-02-19 05:34:19.716 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:828 -   Setting study instance UID index: 1
# 2021-02-19 05:34:19.717 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:get_dicom_info_from_description:31 -     Image modality: CT
# 2021-02-19 05:34:19.717 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:312 -   Processing series UID: 1.3.6.1.4.1.14519.5.2.1.5099.8010.427264300850965737262860055580
# 2021-02-19 05:34:19.718 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:318 -   Number of DICOM files: 113
# 2021-02-19 05:34:19.723 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:340 -   SOP Class name: CT Image Storage
# 2021-02-19 05:34:21.035 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:812 -   Parent sorting field (PatientName) match found: 0522C0001
# 2021-02-19 05:34:21.036 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:828 -   Setting study instance UID index: 2
# 2021-02-19 05:34:21.037 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:get_dicom_info_from_description:31 -     Image modality: CT
# 2021-02-19 05:34:21.038 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:312 -   Processing series UID: 1.3.6.1.4.1.22213.2.26555.2
# 2021-02-19 05:34:21.039 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:318 -   Number of DICOM files: 107
# 2021-02-19 05:34:21.047 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:340 -   SOP Class name: CT Image Storage
# 2021-02-19 05:34:22.118 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:812 -   Parent sorting field (PatientName) match found: 0522C0001
# 2021-02-19 05:34:22.120 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:828 -   Setting study instance UID index: 3
# 2021-02-19 05:34:22.121 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:get_dicom_info_from_description:31 -     Image modality: CT
# 2021-02-19 05:34:22.121 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:get_dicom_info_from_description:43 -     Could not find ProtocolName
# 2021-02-19 05:34:22.122 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:312 -   Processing series UID: 1.3.6.1.4.1.22213.2.26555.3
# 2021-02-19 05:34:22.123 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:318 -   Number of DICOM files: 1
# 2021-02-19 05:34:22.236 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:340 -   SOP Class name: RT Structure Set Storage
# 2021-02-19 05:34:22.238 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:497 -       Number of files: 1
# 2021-02-19 05:34:22.341 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:529 -       Item 0: Matched SeriesInstanceUID = 1.3.6.1.4.1.22213.2.26555.2
# 2021-02-19 05:34:23.292 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:transform_point_set_from_dicom_struct:198 -     Converting structure 0 with name: 1cmptv
# 2021-02-19 05:34:23.706 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:transform_point_set_from_dicom_struct:198 -     Converting structure 1 with name: BRAC_PLX
# 2021-02-19 05:34:24.105 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:transform_point_set_from_dicom_struct:198 -     Converting structure 2 with name: GTV
# 2021-02-19 05:34:24.509 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:transform_point_set_from_dicom_struct:198 -     Converting structure 3 with name: SKIN
# 2021-02-19 05:34:27.430 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:transform_point_set_from_dicom_struct:198 -     Converting structure 4 with name: SPINAL_CORD
# 2021-02-19 05:34:28.045 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:812 -   Parent sorting field (PatientName) match found: 0522C0001
# 2021-02-19 05:34:28.047 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:834 -   Study instance UID index already exists: 3
# 2021-02-19 05:34:28.121 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:312 -   Processing series UID: 1.3.6.1.4.1.22213.2.26555.5.1
# 2021-02-19 05:34:28.123 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:318 -   Number of DICOM files: 1
# 2021-02-19 05:34:28.131 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:340 -   SOP Class name: RT Dose Storage
# 2021-02-19 05:34:28.134 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:554 -       Number of files: 1
# 2021-02-19 05:34:28.169 | DEBUG    | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_series:576 -   Dose grid scaling: 1.438010e-03 Gy
# 2021-02-19 05:34:28.211 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:812 -   Parent sorting field (PatientName) match found: 0522C0001
# 2021-02-19 05:34:28.212 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:process_dicom_directory:834 -   Study instance UID index already exists: 3
# 2021-02-19 05:34:28.213 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:618 -   Writing files for field: IMAGES
# 2021-02-19 05:34:28.214 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/IMAGES/0522C0001_0_CT_ABDOMENPETCT_2.nii.gz
# 2021-02-19 05:34:28.214 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.215 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/IMAGES/0522C0001_1_CT_HEADNECKPETCT_2.nii.gz
# 2021-02-19 05:34:28.216 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.216 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/IMAGES/0522C0001_2_CT_HEADNECKPETCT_2.nii.gz
# 2021-02-19 05:34:28.217 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.218 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/IMAGES/0522C0001_3_CT_1.nii.gz
# 2021-02-19 05:34:28.219 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.221 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:618 -   Writing files for field: STRUCTURES
# 2021-02-19 05:34:28.222 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/STRUCTURES/0522C0001_3_RTSTRUCT_1CMPTV.nii.gz
# 2021-02-19 05:34:28.223 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.224 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/STRUCTURES/0522C0001_3_RTSTRUCT_BRAC_PLX.nii.gz
# 2021-02-19 05:34:28.225 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.226 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/STRUCTURES/0522C0001_3_RTSTRUCT_GTV.nii.gz
# 2021-02-19 05:34:28.227 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.228 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/STRUCTURES/0522C0001_3_RTSTRUCT_SKIN.nii.gz
# 2021-02-19 05:34:28.230 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.236 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/STRUCTURES/0522C0001_3_RTSTRUCT_SPINAL_CORD.nii.gz
# 2021-02-19 05:34:28.238 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.
# 2021-02-19 05:34:28.242 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:618 -   Writing files for field: DOSES
# 2021-02-19 05:34:28.243 | WARNING  | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:692 -   File exists: tcia/Head-Neck Cetuximab/0522c0001/NIFTI/0522C0001/DOSES/0522C0001_3_PLAN.nii.gz
# 2021-02-19 05:34:28.245 | INFO     | platipy.dicom.dicom_directory_crawler.conversion_utils:write_output_data_to_disk:699 -   You have selected to NOT overwrite existing files. Continuing.

# %% [markdown]
# ## Finally, we load the NIFTI data and visualise it

# %%
ct_path = [p for p in data[patient_id]["NIFTI"]["IMAGES"] if p.name.endswith("CT_1.nii.gz")][0]
ct = sitk.ReadImage(str(ct_path))

structures = {s.name.split(".")[0].split("_")[-1]: sitk.ReadImage(str(s)) for s in data[patient_id]["NIFTI"]["STRUCTURES"]}

dose = sitk.ReadImage(str(data[patient_id]["NIFTI"]["DOSES"][0]))
dose = sitk.Resample(dose, ct)

# %%
img_vis = ImageVisualiser(ct, cut=get_com(structures["GTV"]), figure_size_in=10)
img_vis.add_scalar_overlay(dose, colormap="inferno", alpha=0.5)
img_vis.add_contour(structures)
fig = img_vis.show()
