# %%
"""
Import modules
"""

import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt

from scipy.ndimage import measurements

# %matplotlib inline

from platipy.imaging.tests.pull_data import get_lung_data
from platipy.imaging.projects.cardiac.run import run_cardiac_segmentation

# %%
"""
This will download lung cancer patient CT scans, with contours of several structures.
This only has to be done once - if it is ran again don't worry, the same data will not be downloaded again!
"""

images = get_lung_data(number_of_patients=5)

# %%
"""
We define the settings used for the end-to-end segmentation
Check out the guide in "PlatiPy-GettingStarted.pdf" for a description of these settings
"""

settings = {
    "outputFormat": "Auto_{0}.nii.gz",
    "atlasSettings": {
        "atlasIdList": ["101","102","103"],
        "atlasStructures": ["Heart","Esophagus","Lung_L","Lung_R","SpinalCord"],
        "atlasPath": "../../imaging/tests/data/LCTSC",
        "atlasImageFormat": "LCTSC-Test-S1-{0}/CT.nii.gz",
        "atlasLabelFormat": "LCTSC-Test-S1-{0}/Struct_{1}.nii.gz",
        "autoCropAtlas":False
    },
    "autoCropSettings": {"expansion": [0,0,0],},
    "rigidSettings": {
        "initialReg": "Similarity",
        "options": {
            "shrinkFactors": [16, 8, 4],
            "smoothSigmas": [0, 0, 0],
            "samplingRate": 0.75,
            "defaultValue": -1024,
            "numberOfIterations": 15,
            "finalInterp": sitk.sitkBSpline,
            "metric": "mean_squares",
            "optimiser": "gradient_descent"
        },
        "trace": False,
        "guideStructure": False,
    },
    "deformableSettings": {
        "isotropicResample": True,
        "resolutionStaging": [16, 8, 4],  # specify voxel size (mm) since isotropic_resample is set
        "iterationStaging": [15, 15, 15],
        "smoothingSigmas": [4, 2, 1],
        "ncores": 8,
        "trace": False,
    },
    "IARSettings": {
        "referenceStructure": "Heart",
        "smoothDistanceMaps": True,
        "smoothSigma": 1,
        "zScoreStatistic": "MAD",
        "outlierMethod": "IQR",
        "outlierFactor": 1.5,
        "minBestAtlases": 5,
        "project_on_sphere": False,
    },
    "labelFusionSettings": {
        "voteType": "unweighted",
        "voteParams": {},  # No parameters needed for majority voting
        "optimalThreshold": {"Heart":0.5,
                             "Esophagus":0.5,
                             "Lung_L":0.5,
                             "Lung_R":0.5,},
    },
    "vesselSpliningSettings": {
        "vesselNameList": ["SpinalCord"],
        "vesselRadius_mm": {"SpinalCord": 6},
        "spliningDirection": {"SpinalCord": "z"},
        "stopCondition": {"SpinalCord": "count"},
        "stopConditionValue": {"SpinalCord": 1},
    },
    'returnAsCropped': False
}

# %%
"""
Read in the image we want to automatically segment
"""

test_image = sitk.ReadImage('../../imaging/tests/data/LCTSC/LCTSC-Test-S1-104/CT.nii.gz')

# %%
"""
Run autosegmentation!
This will take some time, and will print updates along the way
"""

auto_structures = run_cardiac_segmentation(test_image, settings)
# Out:
# 2020-10-29 15:47:31.401 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:149 -
# 2020-10-29 15:47:36.406 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:222 - Running initial Translation tranform to crop image volume
# 2020-10-29 15:47:36.408 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:226 -   > atlas 101
# 2020-10-29 15:47:54.921 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:226 -   > atlas 102
# 2020-10-29 15:48:17.377 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:226 -   > atlas 103
# 2020-10-29 15:48:41.266 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:269 - Calculated crop box
#                 [0, 0, 0]
#                 [509, 511, 130]
#
#                 Volume reduced by factor 1.0156151784808565
# 2020-10-29 15:48:41.267 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:282 - Running Similarity tranform to align atlas images
# 2020-10-29 15:48:41.269 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:287 -   > atlas 101
# 2020-10-29 15:49:16.551 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:287 -   > atlas 102
# 2020-10-29 15:49:55.785 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:287 -   > atlas 103
# 2020-10-29 15:50:32.971 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:334 - Running DIR to register atlas images
# 2020-10-29 15:50:32.973 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:338 -   > atlas 101
# 2020-10-29 15:51:18.074 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:338 -   > atlas 102
# 2020-10-29 15:51:54.176 | INFO     | platipy.imaging.projects.cardiac.run:run_cardiac_segmentation:338 -   > atlas 103
# 2020-10-29 15:52:42.748 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:180 - Iterative atlas removal:
# 2020-10-29 15:52:42.913 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:181 -   Beginning process
# 2020-10-29 15:52:49.330 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:202 -   Less than 12 atlases, resample factor set: 5
# 2020-10-29 15:52:49.341 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:211 -   Calculating surface distance maps:
# 2020-10-29 15:52:49.342 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:213 -     101
# 2020-10-29 15:52:53.596 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:213 -     102
# 2020-10-29 15:52:57.829 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:213 -     103
# 2020-10-29 15:53:02.132 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:293 -     MAD zero count: 117
# 2020-10-29 15:53:02.134 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:305 -       [101] Statistics of mZ-scores
# 2020-10-29 15:53:02.135 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:306 -         Min(Z)    = -853.78
# 2020-10-29 15:53:02.136 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:308 -         Q1(Z)     = -2.35
# 2020-10-29 15:53:02.137 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:310 -         Mean(Z)   = -4.38
# 2020-10-29 15:53:02.139 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:312 -         Median(Z) = -0.83
# 2020-10-29 15:53:02.140 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:315 -         Q3(Z)     = -0.14
# 2020-10-29 15:53:02.142 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:317 -         Max(Z)    = 47.95
#
# 2020-10-29 15:53:02.293 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:293 -     MAD zero count: 121
# 2020-10-29 15:53:02.296 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:305 -       [102] Statistics of mZ-scores
# 2020-10-29 15:53:02.299 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:306 -         Min(Z)    = -237.56
# 2020-10-29 15:53:02.300 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:308 -         Q1(Z)     = -1.04
# 2020-10-29 15:53:02.301 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:310 -         Mean(Z)   = 0.20
# 2020-10-29 15:53:02.303 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:312 -         Median(Z) = -0.02
# 2020-10-29 15:53:02.305 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:315 -         Q3(Z)     = 1.17
# 2020-10-29 15:53:02.310 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:317 -         Max(Z)    = 112.26
#
# 2020-10-29 15:53:02.332 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:293 -     MAD zero count: 128
# 2020-10-29 15:53:02.334 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:305 -       [103] Statistics of mZ-scores
# 2020-10-29 15:53:02.336 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:306 -         Min(Z)    = -438.12
# 2020-10-29 15:53:02.338 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:308 -         Q1(Z)     = 0.03
# 2020-10-29 15:53:02.339 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:310 -         Mean(Z)   = 4.03
# 2020-10-29 15:53:02.341 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:312 -         Median(Z) = 0.84
# 2020-10-29 15:53:02.344 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:315 -         Q3(Z)     = 2.87
# 2020-10-29 15:53:02.345 | DEBUG    | platipy.imaging.atlas.iterative_atlas_removal:run_iar:317 -         Max(Z)    = 467.64
#
# 2020-10-29 15:53:02.374 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:357 -   Analysing results
# 2020-10-29 15:53:02.377 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:358 -    Outlier limit: 16.077
# 2020-10-29 15:53:02.378 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:366 - 0,101 102 103,9.835 3.282 10.9,16.08
#
# 2020-10-29 15:53:02.384 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:376 -       101: Q = 09.835 [KEEP]
# 2020-10-29 15:53:02.386 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:376 -       102: Q = 03.282 [KEEP]
# 2020-10-29 15:53:02.387 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:376 -       103: Q = 10.897 [KEEP]
# 2020-10-29 15:53:02.388 | INFO     | platipy.imaging.atlas.iterative_atlas_removal:run_iar:411 -   End point reached. Keeping:
#    ['101', '102', '103']

# %%
"""
Optionally write the automatic segmentations to disk
"""
output_name = settings["outputFormat"]

for struct_name in list(auto_structures.keys()):
    sitk.WriteImage(auto_structures[struct_name], output_name.format(struct_name))

# %%
"""
Next, we can generate a nice figure to check what the segmentation looks like

The first step here is to convert SimpleITK images to NumPy arrays
"""

image_arr = sitk.GetArrayFromImage(test_image)
auto_structures_arr = {struct:sitk.GetArrayFromImage(auto_structures[struct]) for struct in auto_structures.keys()}

# %%
"""
Next, we define where the orthogonal image slices will pass through, as well as the figure size and colours used for contours
"""

z,y,x = np.array(measurements.center_of_mass(auto_structures_arr['Heart']), dtype=np.int)

(SagSize, CorSize, AxSize) = test_image.GetSize()
spPlane, _, spSlice = test_image.GetSpacing()
asp = (spSlice/spPlane)

fSize = (12, 12.0*(asp*AxSize+CorSize)/(1.0*SagSize+CorSize))

color_list = plt.cm.Spectral(np.linspace(0,1,len(auto_structures_arr.keys())))

# %%
"""
Now generate the figure, which should be displayed below!
"""

fig, ((axAx, blank), (axCor, axSag)) = plt.subplots(2, 2, figsize=fSize,gridspec_kw = {'height_ratios':[CorSize,asp*AxSize],'width_ratios': [SagSize,CorSize]})
blank.axis('off')

imAx = axAx.imshow(image_arr[z,:,:], cmap=plt.cm.gray)
axAx.axis('off')

imCor = axCor.imshow(image_arr[:,y,:], origin='lower', aspect=asp, cmap=plt.cm.gray)
axCor.axis('off')

imSag = axSag.imshow(image_arr[:,:,x], origin='lower', aspect=asp, cmap=plt.cm.gray)
axSag.axis('off')

for i, struct in enumerate(auto_structures.keys()):
    colour = color_list[i,:3]
    temp = axAx.contour(auto_structures_arr[struct][z,:,:], levels=[0], linewidths=2, colors=[colour])
    temp.collections[0].set_label(struct)
    axCor.contour(auto_structures_arr[struct][:,y,:], levels=[0], linewidths=2, colors=[colour])
    axSag.contour(auto_structures_arr[struct][:,:,x], levels=[0], linewidths=2, colors=[colour])

vmin = -250; window=500
imAx.set_clim(vmin,vmin+window)
imCor.set_clim(vmin,vmin+window)
imSag.set_clim(vmin,vmin+window)

axAx.legend(loc='center left', bbox_to_anchor=(1.05,0.5))

fig.subplots_adjust(left=0, right=1, wspace=0.01, hspace=0.01, top=1, bottom=0)
fig.show()
# Out:
# No contour levels were found within the data range.
# No contour levels were found within the data range.
# No contour levels were found within the data range.
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# %matplotlib inline
