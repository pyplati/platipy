# %%
import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %matplotlib notebook
# %matplotlib notebook

from platipy.visualisation import vis_tools

# %%
image = sitk.ReadImage('../../segmentation/tests/data/dynamic/lung/LCTSC-Train-S1-008/CT.nii.gz')

structure_name_list = ["Heart","Esophagus","Lung_L","Lung_R", "SpinalCord"]
contours = {s:sitk.ReadImage(f'../../segmentation/examples/Auto_{s}.nii.gz') for s in structure_name_list}

# %%
fig, ax, cut = vis_tools.displaySlice(image);
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
vis_tools.overlayContour(contours, fig, ax, cut, True, plt.cm.Spectral)
# Out:
# /platipy/platipy/visualisation/vis_tools.py:222: UserWarning: No contour levels were found within the data range.
#   temp = axAx.contour(plot_dict[c_name].__getitem__(sAx), levels=[0], linewidths=2, colors=[colors[index]])
# /platipy/platipy/visualisation/vis_tools.py:225: UserWarning: No contour levels were found within the data range.
#   axCor.contour(plot_dict[c_name].__getitem__(sCor), levels=[0], linewidths=2, colors=[colors[index]])
# /platipy/platipy/visualisation/vis_tools.py:226: UserWarning: No contour levels were found within the data range.
#   axSag.contour(plot_dict[c_name].__getitem__(sSag), levels=[0], linewidths=2, colors=[colors[index]])
# <img src="data:image/png;base64,..." width="600">
